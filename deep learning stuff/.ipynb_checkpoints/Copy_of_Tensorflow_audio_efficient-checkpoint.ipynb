# %% [markdown]
# Adapted from: https://www.tensorflow.org/tutorials/audio/simple_audio
# ##### Copyright 2020 The TensorFlow Authors.

# %%
#@title Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %% [markdown]
# ## Run the two cells below, and then restart the kernel and skip these two

# %%
# !pip uninstall tensorflow
# !pip uninstall tensorflow-io
# !pip install tensorflow-gpu
# !pip install --no-deps tensorflow-io
# Out:
# Found existing installation: tensorflow 2.8.2+zzzcolab20220719082949
# Uninstalling tensorflow-2.8.2+zzzcolab20220719082949:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-2.8.2+zzzcolab20220719082949.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.8.2+zzzcolab20220719082949
# WARNING: Skipping tensorflow-io as it is not installed.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 511.7 MB 5.9 kB/s
# ...
#      |████████████████████████████████| 438 kB 57.9 MB/s
# ...

# %%
# !apt install --allow-change-held-packages libcudnn8=8.1.0.77-1+cuda11.2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following packages will be REMOVED:
#   libcudnn8-dev
# The following held packages will be changed:
#   libcudnn8
# The following packages will be upgraded:
#   libcudnn8
# 1 upgraded, 0 newly installed, 1 to remove and 18 not upgraded.
# Need to get 430 MB of archives.
# After this operation, 3,139 MB disk space will be freed.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcudnn8 8.1.0.77-1+cuda11.2 [430 MB]
# Fetched 430 MB in 10s (44.0 MB/s)
# (Reading database ... 155676 files and directories currently installed.)
# Removing libcudnn8-dev (8.0.5.39-1+cuda11.1) ...
# (Reading database ... 155654 files and directories currently installed.)
# ...

# %%
import os
import pathlib

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf
import tensorflow_io as tfio
from tensorflow.keras import layers
from tensorflow.keras import models
from IPython import display

# Set the seed value for experiment reproducibility.
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %% [markdown]
# ## Import the mini Speech Commands dataset
#
# * Take a look on the left using the file explorer

# %%
DATASET_PATH = 'data/mini_speech_commands'

data_dir = pathlib.Path(DATASET_PATH)
if not data_dir.exists():
  tf.keras.utils.get_file(
      'mini_speech_commands.zip',
      origin="http://storage.googleapis.com/download.tensorflow.org/data/mini_speech_commands.zip",
      extract=True,
      cache_dir='.', cache_subdir='data')
# Out:
# ...
# 182082353/182082353 [==============================] - 1s 0us/step

# %% [markdown]
# The dataset's audio clips are stored in eight folders corresponding to each speech command: `no`, `yes`, `down`, `go`, `left`, `up`, `right`, and `stop`:
#
# These are stored in ./data/mini_speech_commands/

# %%
# Here we list all the files (folders) in /data/mini_speech_command
commands = np.array(tf.io.gfile.listdir(str(data_dir)))

# We want everything except for the readme file
commands = commands[commands != 'README.md']
print('Commands:', commands)
# Out:
# Commands: ['down' 'yes' 'up' 'no' 'left' 'right' 'go' 'stop']

# %%
data_dir
# Out:
# PosixPath('data/mini_speech_commands')

# %%
# This allows us to get the listing of all the files name which is
# inside the data_dir folder but going two steps into the folder
# structure due to the /*/*. Here the star means everything (all files)
filenames = tf.io.gfile.glob(str(data_dir) + '/*/*')

# Shuffle the files
filenames = tf.random.shuffle(filenames)
num_samples = len(filenames)

print('Number of total examples:', num_samples)
print('Number of examples per label:',
      len(tf.io.gfile.listdir(str(data_dir/commands[0]))))

# Check the number of files in each sub folder
for i in range (0, len(commands)):
  print('Number of examples per label '+commands[i]+' ',
      len(tf.io.gfile.listdir(str(data_dir/commands[i]))))
print()
print('Example file tensor:', filenames[0])
# Out:
# Number of total examples: 8000
# Number of examples per label: 1000
# Number of examples per label down  1000
# Number of examples per label yes  1000
# Number of examples per label up  1000
# Number of examples per label no  1000
# Number of examples per label left  1000
# Number of examples per label right  1000
# Number of examples per label go  1000
# Number of examples per label stop  1000
#
# Example file tensor: tf.Tensor(b'data/mini_speech_commands/stop/338dacf5_nohash_0.wav', shape=(), dtype=string)

# %% [markdown]
# Split `filenames` into training, validation and test sets using a 80:10:10 ratio, respectively:

# %%
train_files = filenames[:6400]
val_files = filenames[6400: 6400 + 800]
test_files = filenames[-800:]

print('Training set size', len(train_files))
print('Validation set size', len(val_files))
print('Test set size', len(test_files))
# Out:
# Training set size 6400
# Validation set size 800
# Test set size 800

# %% [markdown]
# ## Read the audio files and their labels

# %% [markdown]
# In this section you will preprocess the dataset, creating decoded tensors for the waveforms and the corresponding labels. Note that:
#
# - Each WAV file contains time-series data with a set number of samples per second.
# - Each sample represents the <a href="https://en.wikipedia.org/wiki/Amplitude" class="external">amplitude</a> of the audio signal at that specific time.
# - The <a href="https://en.wikipedia.org/wiki/Sampling_(signal_processing)#Audio_sampling" class="external">sample rate</a> for this dataset is 16kHz.
#
# The shape of the tensor returned by `tf.audio.decode_wav` is `[samples, channels]`, where `channels` is `1` for mono or `2` for stereo. The mini Speech Commands dataset only contains mono recordings.

# %%
test_file = tf.io.read_file(DATASET_PATH+'/down/0a9f9af7_nohash_0.wav')

# The function below returns two things, the amplitude values and the sampling rate
# but we don't need the sampling rate
test_audio, sample_rate = tf.audio.decode_wav(contents=test_file)
sample_rate = tf.cast(sample_rate, dtype=tf.int64)
print(sample_rate.numpy())
test_audio = tfio.audio.resample(test_audio, sample_rate.numpy(), 8000)
test_audio.shape
# Out:
# 16000
# TensorShape([6827, 1])

# %% [markdown]
# Now, let's define a function that preprocesses the dataset's raw WAV audio files into audio tensors:
#
# * We take in the file name
# * Use the decode_wav function
# * Get ride of the "mono" dimension

# %%
def decode_audio(audio_binary):
  # Decode WAV-encoded audio files to `float32` tensors, normalized
  # to the [-1.0, 1.0] range. Return `float32` audio and a sample rate.
  audio, sample_rate = tf.audio.decode_wav(contents=audio_binary)
  sample_rate = tf.cast(sample_rate, dtype=tf.int64)
  audio = tfio.audio.resample(audio, sample_rate, 8000)
  return tf.squeeze(audio, axis=-1), sample_rate

# %%
train_files[0]
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'data/mini_speech_commands/stop/338dacf5_nohash_0.wav'>

# %%
parts = tf.strings.split(
      input=train_files[0],
      sep=os.path.sep)
parts.numpy()
# Out:
# array([b'data', b'mini_speech_commands', b'stop',
#        b'338dacf5_nohash_0.wav'], dtype=object)

# %% [markdown]
# Now we need to way to assign labels. We can use the name of the folders, e.g. "down", "up" etc... But we need a way to get them. We can use the path, and separate the path string using whatever the system is using to deliminate the path, typically "/". See below

# %% [markdown]
# If we look at the last element in the list (-1 in Python means last) we get the file name

# %%
parts.numpy()[-1]
# Out:
# b'338dacf5_nohash_0.wav'

# %% [markdown]
# And just before than (i.e. one more step to the left) we get the folder name

# %%
parts.numpy()[-2]
# Out:
# b'stop'

# %% [markdown]
# Define a function that creates labels using the parent directories for each file:

# %%
def get_label(file_path):
  parts = tf.strings.split(
      input=file_path,
      sep=os.path.sep)

  return parts[-2]

# %% [markdown]
# Define another helper function—`get_waveform_and_label`—that puts it all together:
#
# This function will first get the label from the file path and then get the amplitude values by reading the audio file.

# %%
def get_waveform_and_label(file_path):
  label = get_label(file_path)
  audio_binary = tf.io.read_file(file_path)
  waveform, sample_rate = decode_audio(audio_binary)
  
  return waveform, label

# %% [markdown]
# Build the training set to extract the audio-label pairs:
#
# - Create a `tf.data.Dataset`
# - We will use the map function (https://www.tensorflow.org/api_docs/python/tf/data/Dataset#map) which allows us to tell Tensorflow to call the function we just made on all of the data.
# - This operation can be done in parallel to speed things up. We use ``AUTOTUNE = tf.data.AUTOTUNE`` to enable Tensorflow to figure out how much CPU to allow to this parallel operation.

# %%
AUTOTUNE = tf.data.AUTOTUNE

files_ds = tf.data.Dataset.from_tensor_slices(train_files)

waveform_ds = files_ds.map(
    map_func=get_waveform_and_label,
    num_parallel_calls=AUTOTUNE)
# Out:
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample

# %% [markdown]
# ## Small detour
#
# We want to filter out all audio files which have a length not equal to 8000. To do this, we need to create a filter. Below is a small example to illustrate the idea.
#
# If the filter returns true, then that data is kept, otherwise it is discarded.

# %%
# Create some data
dataset = tf.data.Dataset.from_tensor_slices([1, 2, 3])

# Create the filter
def filter_fn(x):
  return tf.math.equal(x, 1)

# Apply the filter
dataset = dataset.filter(filter_fn)

# View the results
list(dataset.as_numpy_iterator())
# Out:
# [1]

# %%
# Our filter takes 2 things since the dataset is
# made up of audio amplitudes and labels since this
# is how we coded it above in the function get_waveform_and_label
def filter_fn(x, y):
  print(x)
  print(y)
  return tf.math.equal(len(x), 8000)

# So the function will discard all examples which are not of length
# equal to 8000
waveform_ds = waveform_ds.filter(filter_fn)
for x, y in waveform_ds.take(1):
  print(x.numpy().shape)
  print(y.numpy())
# Out:
# Tensor("args_0:0", dtype=float32)
# Tensor("args_1:0", shape=(), dtype=string)
# (8000,)
# b'stop'

# %% [markdown]
# Let's plot a few audio waveforms:

# %%
rows = 3
cols = 3
n = rows * cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 12))

for i, (audio, label) in enumerate(waveform_ds.take(n)):
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  ax.plot(audio.numpy())
  ax.set_yticks(np.arange(-1.2, 1.2, 0.2))
  label = label.numpy().decode('utf-8')
  ax.set_title(label)

plt.show()

# %% [markdown]
# Okay so we are not quite there yet. So far we can:
#
# * Find all the file names
# * Read the file names and read the audio files
# * Get the labels
# * Then process this in parallel to create a Dataset object.
#
# But we won't train the network on the waveform, we want spectrograms. The next part adds this on.

# %% [markdown]
# ## Convert waveforms to spectrograms

# %%
def get_spectrogram(waveform):
  # Zero-padding for an audio waveform with less than 16,000 samples.
  #input_len = 16000
  #waveform = waveform[:input_len]
  #zero_padding = tf.zeros(
  #    [16000] - tf.shape(waveform),
  #    dtype=tf.float32)
  # Cast the waveform tensors' dtype to float32.
  waveform = tf.cast(waveform, dtype=tf.float32)
  # Concatenate the waveform with `zero_padding`, which ensures all audio
  # clips are of the same length.
  #equal_length = tf.concat([waveform, zero_padding], 0)
  # Convert the waveform to a spectrogram via a STFT.
  spectrogram = tf.signal.stft(
      waveform, frame_length=255, frame_step=128)
  # Obtain the magnitude of the STFT.
  spectrogram = tf.abs(spectrogram)
  # Add a `channels` dimension, so that the spectrogram can be used
  # as image-like input data with convolution layers (which expect
  # shape (`batch_size`, `height`, `width`, `channels`).
  spectrogram = spectrogram[..., tf.newaxis]
  return spectrogram

# %% [markdown]
# Next, start exploring the data. Print the shapes of one example's tensorized waveform and the corresponding spectrogram, and play the original audio:

# %%
for waveform, label in waveform_ds.take(1):
  label = label.numpy().decode('utf-8')
  spectrogram = get_spectrogram(waveform)

print('Label:', label)
print('Waveform shape:', waveform.shape)
print('Spectrogram shape:', spectrogram.shape)
print('Audio playback')
display.display(display.Audio(waveform, rate=16000))
# Out:
# Label: stop
# Waveform shape: (8000,)
# Spectrogram shape: (61, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Now, define a function for displaying a spectrogram:

# %%
def plot_spectrogram(spectrogram, ax):
  if len(spectrogram.shape) > 2:
    assert len(spectrogram.shape) == 3
    spectrogram = np.squeeze(spectrogram, axis=-1)
  # Convert the frequencies to log scale and transpose, so that the time is
  # represented on the x-axis (columns).
  # Add an epsilon to avoid taking a log of zero.
  log_spec = np.log(spectrogram.T + np.finfo(float).eps)
  height = log_spec.shape[0]
  width = log_spec.shape[1]
  X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
  Y = range(height)
  ax.pcolormesh(X, Y, log_spec)

# %% [markdown]
# Plot the example's waveform over time and the corresponding spectrogram (frequencies over time):

# %%
fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, 8000])

plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.show()

# %% [markdown]
# Now, define a function that transforms the waveform dataset into spectrograms and their corresponding labels as integer IDs:

# %%
def get_spectrogram_and_label_id(audio, label):
  spectrogram = get_spectrogram(audio)
  label_id = tf.math.argmax(label == commands)
  return spectrogram, label_id

# %% [markdown]
# Map `get_spectrogram_and_label_id` across the dataset's elements with `Dataset.map`:

# %%
spectrogram_ds = waveform_ds.map(
  map_func=get_spectrogram_and_label_id,
  num_parallel_calls=AUTOTUNE)

# %% [markdown]
# Examine the spectrograms for different examples of the dataset:

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 10))

for i, (spectrogram, label_id) in enumerate(spectrogram_ds.take(n)):
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  plot_spectrogram(spectrogram.numpy(), ax)
  ax.set_title(commands[label_id.numpy()])
  ax.axis('off')

plt.show()

# %% [markdown]
# ## Build and train the model
#
# Repeat the training set preprocessing on the validation and test sets:

# %%
def preprocess_dataset(files):
  files_ds = tf.data.Dataset.from_tensor_slices(files)
  output_ds = files_ds.map(
      map_func=get_waveform_and_label,
      num_parallel_calls=AUTOTUNE)
  output_ds = output_ds.filter(filter_fn)
  output_ds = output_ds.map(
      map_func=get_spectrogram_and_label_id,
      num_parallel_calls=AUTOTUNE)
  return output_ds

# %%
train_ds = spectrogram_ds
val_ds = preprocess_dataset(val_files)
test_ds = preprocess_dataset(test_files)
# Out:
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# Tensor("args_0:0", dtype=float32)
# Tensor("args_1:0", shape=(), dtype=string)
# Tensor("args_0:0", dtype=float32)
# Tensor("args_1:0", shape=(), dtype=string)

# %% [markdown]
# Batch the training and validation sets for model training:

# %%
batch_size = 64
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %% [markdown]
# Add `Dataset.cache` and `Dataset.prefetch` operations to reduce read latency while training the model:

# %%
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
len(list(train_ds))
# Out:
# 90

# %% [markdown]
# For the model, you'll use a simple convolutional neural network (CNN), since you have transformed the audio files into spectrogram images.
#
# Your `tf.keras.Sequential` model will use the following Keras preprocessing layers:
#
# - `tf.keras.layers.Resizing`: to downsample the input to enable the model to train faster.
# - `tf.keras.layers.Normalization`: to normalize each pixel in the image based on its mean and standard deviation.
#
# For the `Normalization` layer, its `adapt` method would first need to be called on the training data in order to compute aggregate statistics (that is, the mean and the standard deviation).

# %%
for spectrogram, _ in spectrogram_ds.take(1):
  input_shape = spectrogram.shape
print('Input shape:', input_shape)
num_labels = len(commands)


model = models.Sequential([
    #layers.Input(shape=input_shape),
    layers.Conv2D(32, 3, activation='relu', input_shape=(61, 129, 1)),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(2),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(2),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(2),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])

model.summary()
# Out:
# Input shape: (61, 129, 1)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 59, 127, 32)       320
#
#  conv2d_1 (Conv2D)           (None, 57, 125, 64)       18496
#
#  max_pooling2d (MaxPooling2D  (None, 28, 62, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 26, 60, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 30, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 28, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 14, 64)        0
#  2D)
#
#  flatten (Flatten)           (None, 4480)              0
#
#  dense (Dense)               (None, 64)                286784
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 8)                 520
#
# ...
# Total params: 379,976
# Trainable params: 379,976
# Non-trainable params: 0
# ...

# %% [markdown]
# Configure the Keras model with the Adam optimizer and the cross-entropy loss:

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %% [markdown]
# Train the model over 10 epochs for demonstration purposes:
#
# Run this cell a few times

# %%
EPOCHS = 5
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS, steps_per_epoch=16
)
# Out:
# Epoch 1/5
# 16/16 [==============================] - 2s 117ms/step - loss: 0.6723 - accuracy: 0.7656 - val_loss: 0.6183 - val_accuracy: 0.7969
# Epoch 2/5
# 16/16 [==============================] - 1s 92ms/step - loss: 0.7214 - accuracy: 0.7568 - val_loss: 0.5858 - val_accuracy: 0.8025
# Epoch 3/5
# 16/16 [==============================] - 2s 102ms/step - loss: 0.6557 - accuracy: 0.7754 - val_loss: 0.5582 - val_accuracy: 0.8261
# Epoch 4/5
# 16/16 [==============================] - 1s 96ms/step - loss: 0.6267 - accuracy: 0.7939 - val_loss: 0.5573 - val_accuracy: 0.8178
# Epoch 5/5
# 16/16 [==============================] - 2s 98ms/step - loss: 0.6221 - accuracy: 0.7744 - val_loss: 0.5834 - val_accuracy: 0.8067

# %% [markdown]
# Let's plot the training and validation loss curves to check how your model has improved during training:

# %%
metrics = history.history
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.show()

# %% [markdown]
# ## Evaluate the model performance
#
# Run the model on the test set and check the model's performance:

# %%
test_audio = []
test_labels = []

for audio, label in test_ds:
  test_audio.append(audio.numpy())
  test_labels.append(label.numpy())

test_audio = np.array(test_audio)
test_labels = np.array(test_labels)

# %%
y_pred = np.argmax(model.predict(test_audio), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Test set accuracy: {test_acc:.0%}')
# Out:
# 23/23 [==============================] - 1s 13ms/step
# Test set accuracy: 79%

# %% [markdown]
# ### Display a confusion matrix
#
# Use a <a href="https://developers.google.com/machine-learning/glossary#confusion-matrix" class="external">confusion matrix</a> to check how well the model did classifying each of the commands in the test set:

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=commands,
            yticklabels=commands,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# ## Run inference on an audio file
#
# Finally, verify the model's prediction output using an input audio file of someone saying "no". How well does your model perform?

# %%
sample_file = data_dir/'no/01bb6a2a_nohash_0.wav'

sample_ds = preprocess_dataset([str(sample_file)])

for spectrogram, label in sample_ds.batch(1):
  prediction = model(spectrogram)
  plt.bar(commands, tf.nn.softmax(prediction[0]))
  plt.title(f'Predictions for "{commands[label[0]]}"')
  plt.show()
# Out:
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# Tensor("args_0:0", dtype=float32)
# Tensor("args_1:0", shape=(), dtype=string)

# %% [markdown]
# As the output suggests, your model should have recognized the audio command as "no".
